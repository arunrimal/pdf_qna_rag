# %%
# test_dim.py
import os
from dotenv import load_dotenv
from llama_index.embeddings.google_genai import GoogleGenAIEmbedding

load_dotenv()
GEMINI_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
# # Try creating the model exactly as you did in main.py
# embed_model = GoogleGenAIEmbedding(model_name="models/gemini-embedding-004", api_key=api_key)

# # Get the dimension size directly from the object
# print(f"Model Name: {embed_model.model_name}")
# print(f"Embedding Dimension: {embed_model}")
# Out:
# Model Name: models/gemini-embedding-004
# Embedding Dimension: model_name='models/gemini-embedding-004' embed_batch_size=10 callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x000001205B096D90> num_workers=None embeddings_cache=None rate_limiter=None embedding_config=None retries=3 timeout=60 retry_min_seconds=1.0 retry_max_seconds=60.0 retry_exponential_base=2.0

# %%
# from llama_index.embeddings.google import GoogleGenAIEmbedding

embed_model = GoogleGenAIEmbedding(
    model_name="models/gemini-embedding-001",
    api_key=GEMINI_API_KEY,
    output_dimensionality=768
)

test = embed_model.get_text_embedding("hello world")
print(f"Actual output dimension: {len(test)}")
# Out:
# Actual output dimension: 3072

# %%
embed_model = GoogleGenAIEmbedding(
    model_name="text-embedding-004",
    api_key=GEMINI_API_KEY
)

# Verify
test = embed_model.get_text_embedding("hello world")
print(f"Actual output dimension: {len(test)}")  # Should print 768
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[16], line 7
#       1 embed_model = GoogleGenAIEmbedding(
#       2     model_name="text-embedding-004",
#       3     api_key=GEMINI_API_KEY
#       4 )
#       6 # Verify
# ----> 7 test = embed_model.get_text_embedding("hello world")
#       8 print(f"Actual output dimension: {len(test)}")  # Should print 768
#
# File c:\Users\aarun\anaconda3\envs\pdf_qna_rag\Lib\site-packages\llama_index_instrumentation\dispatcher.py:413, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     410             _logger.debug(f"Failed to reset active_span_id: {e}")
#     412 try:
# --> 413     result = func(*args, **kwargs)
#     414     if isinstance(result, asyncio.Future):
#     415         # If the result is a Future, wrap it
#     416         new_future = asyncio.ensure_future(result)
#
# ...

# %%
import google.generativeai as genai

genai.configure(api_key=GEMINI_API_KEY)

for model in genai.list_models():
    if "embed" in model.name.lower():
        print(model.name, "|", model.supported_generation_methods)
# Out:
# models/gemini-embedding-001 | ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
# models/gemini-embedding-2-preview | ['embedContent', 'countTextTokens', 'countTokens', 'asyncBatchEmbedContent']
